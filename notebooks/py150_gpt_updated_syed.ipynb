# %% [markdown]
# # Clone CodeXGLUE Repo

# %%
# !git clone https://github.com/microsoft/CodeXGLUE.git
# !git clone -b GPT-NeoX-Colab https://github.com/markNZed/CodeXGLUE.git
# Out:
# Cloning into 'CodeXGLUE'...
# remote: Enumerating objects: 3374, done.
# remote: Counting objects: 100% (3373/3373), done.
# remote: Compressing objects: 100% (1535/1535), done.
# remote: Total 3374 (delta 1746), reused 3328 (delta 1733), pack-reused 1 (from 1)
# Receiving objects: 100% (3374/3374), 213.16 MiB | 10.45 MiB/s, done.
# Resolving deltas: 100% (1746/1746), done.
# Updating files: 100% (400/400), done.

# %%
# %cd /content
# !git lfs install
# !git clone https://github.com/markNZed/GPT-NeoX-Colab.git
# %cd /content/GPT-NeoX-Colab/data
# !tar -xf py150_preprocessed.tar.gz
# !mkdir -p /content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion
# !cp py150_preprocessed/* /content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion
# %cd /content
# Out:
# /content
# Git LFS initialized.
# Cloning into 'GPT-NeoX-Colab'...
# remote: Enumerating objects: 496, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 496 (delta 42), reused 48 (delta 17), pack-reused 397 (from 1)
# Receiving objects: 100% (496/496), 113.89 MiB | 24.20 MiB/s, done.
# Resolving deltas: 100% (254/254), done.
# Filtering content: 100% (2/2), 158.65 MiB | 51.44 MiB/s, done.
# /content/GPT-NeoX-Colab/data
# /content

# %% [markdown]
# # Downloading and Preprocessing Dataset

# %%
import os

# Define the file path you want to check for existence
file_path = "/content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion"  # Replace with the actual file name you want to check

# Check if the file exists
if not os.path.exists(file_path):
    # Change directory
    # %cd /content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150
    # Run the shell script to download and extract
    # !bash /content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/download_and_extract.sh
    # Run the preprocessing Python script
    # !python preprocess.py --base_dir=py150_files --output_dir=token_completion
else:
    print("File already exists, skipping download and preprocessing.")
# Out:
# File already exists, skipping download and preprocessing.

# %% [markdown]
# # Cloning GPT-NeoX Repo

# %%
# %cd /content/
# !git clone https://github.com/EleutherAI/gpt-neox.git
# Out:
# /content
# Cloning into 'gpt-neox'...
# remote: Enumerating objects: 19496, done.
# remote: Counting objects: 100% (1699/1699), done.
# remote: Compressing objects: 100% (821/821), done.
# remote: Total 19496 (delta 1254), reused 1202 (delta 870), pack-reused 17797 (from 1)
# Receiving objects: 100% (19496/19496), 113.66 MiB | 36.44 MiB/s, done.
# Resolving deltas: 100% (14113/14113), done.

# %% [markdown]
# # Install Dependencies

# %%
# %%time
# %cd /content/gpt-neox
# Could not redirect to /dev/null in the standard Colab notebook (maybe no output for a particular time?)
# Currently deepspeed from GTP-NeoX is not compatible with logging in torch >= 2.4
# !pip install torch==2.3 torchaudio==2.3.0 torchvision==0.18.0 transformers==4.41.0 sentence-transformers==2.2.2
# !pip install -r ./requirements/requirements.txt
# Out:
# /content/gpt-neox
# Collecting torch==2.3
#   Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.3.0
#   Downloading torchaudio-2.3.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.18.0
#   Downloading torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting transformers==4.41.0
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.9 MB/s eta 0:00:00
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.0 (from torch==2.3)
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.18.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.18.0) (10.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0) (4.66.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.13.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3) (3.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.0) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.2) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3) (1.3.0)
# Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.9 MB/s eta 0:00:00
# Downloading torchaudio-2.3.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 66.4 MB/s eta 0:00:00
# Downloading torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 75.1 MB/s eta 0:00:00
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 81.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 106.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 85.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.6 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 7.3 MB/s eta 0:00:00
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=27054ca119fec57bea897e4fe4e19fed0534ebb8f492bd9ac63381783099533a
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, transformers, torchvision, torchaudio, sentence-transformers
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.3.3
#     Uninstalling nvidia-cublas-cu12-12.6.3.3:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.3.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.0+cu121
#     Uninstalling torchvision-0.20.0+cu121:
#       Successfully uninstalled torchvision-0.20.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.0+cu121
#     Uninstalling torchaudio-2.5.0+cu121:
#       Successfully uninstalled torchaudio-2.5.0+cu121
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.2.1
#     Uninstalling sentence-transformers-3.2.1:
#       Successfully uninstalled sentence-transformers-3.2.1
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.2.2 torch-2.3.0 torchaudio-2.3.0 torchvision-0.18.0 transformers-4.41.0 triton-2.3.0
# Collecting deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed (from -r ./requirements/requirements.txt (line 1))
#   Cloning https://github.com/EleutherAI/DeeperSpeed.git (to revision 02e2ebf7dee6aaab3d89094ed470a4609763c742) to /tmp/pip-install-2rewk7om/deepspeed_2399ff0294c8424db7f1d818ecb9ab92
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/DeeperSpeed.git /tmp/pip-install-2rewk7om/deepspeed_2399ff0294c8424db7f1d818ecb9ab92
#   Running command git rev-parse -q --verify 'sha^02e2ebf7dee6aaab3d89094ed470a4609763c742'
#   Running command git fetch -q https://github.com/EleutherAI/DeeperSpeed.git 02e2ebf7dee6aaab3d89094ed470a4609763c742
#   Running command git checkout -q 02e2ebf7dee6aaab3d89094ed470a4609763c742
#   Resolved https://github.com/EleutherAI/DeeperSpeed.git to commit 02e2ebf7dee6aaab3d89094ed470a4609763c742
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting lm_dataformat@ git+https://github.com/EleutherAI/lm_dataformat.git@4eec05349977071bf67fc072290b95e31c8dd836 (from -r ./requirements/requirements.txt (line 5))
#   Cloning https://github.com/EleutherAI/lm_dataformat.git (to revision 4eec05349977071bf67fc072290b95e31c8dd836) to /tmp/pip-install-2rewk7om/lm-dataformat_50bb0a5bb85c4c3db55f77e6c7e66f3e
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm_dataformat.git /tmp/pip-install-2rewk7om/lm-dataformat_50bb0a5bb85c4c3db55f77e6c7e66f3e
#   Running command git rev-parse -q --verify 'sha^4eec05349977071bf67fc072290b95e31c8dd836'
#   Running command git fetch -q https://github.com/EleutherAI/lm_dataformat.git 4eec05349977071bf67fc072290b95e31c8dd836
#   Resolved https://github.com/EleutherAI/lm_dataformat.git to commit 4eec05349977071bf67fc072290b95e31c8dd836
#   Preparing metadata (setup.py) ... done
# Collecting ftfy>=6.0.1 (from -r ./requirements/requirements.txt (line 2))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface_hub>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 3)) (0.24.7)
# Requirement already satisfied: jinja2==3.1.4 in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 4)) (3.1.4)
# Collecting lm_eval<=0.4.1,>=0.4.0 (from -r ./requirements/requirements.txt (line 6))
#   Downloading lm_eval-0.4.1-py3-none-any.whl.metadata (27 kB)
# Collecting mpi4py>=3.0.3 (from -r ./requirements/requirements.txt (line 7))
#   Downloading mpi4py-4.0.1.tar.gz (466 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.2/466.2 kB 13.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 8)) (1.26.4)
# Collecting pybind11>=2.6.2 (from -r ./requirements/requirements.txt (line 9))
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 10)) (2024.9.11)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 12)) (1.16.0)
# Collecting tiktoken>=0.1.2 (from -r ./requirements/requirements.txt (line 13))
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r ./requirements/requirements.txt (line 14)) (0.19.1)
# Collecting transformers==4.38.0 (from -r ./requirements/requirements.txt (line 15))
#   Downloading transformers-4.38.0-py3-none-any.whl.metadata (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2==3.1.4->-r ./requirements/requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (3.16.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (2.32.3)
# Collecting tokenizers>=0.12.1 (from -r ./requirements/requirements.txt (line 14))
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (4.66.6)
# Collecting hjson (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting ninja (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1))
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (2.9.2)
# Collecting pynvml (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1))
#   Downloading pynvml-11.5.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.0.1->-r ./requirements/requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.11.0->-r ./requirements/requirements.txt (line 3)) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.11.0->-r ./requirements/requirements.txt (line 3)) (4.12.2)
# Collecting zstandard (from lm_dataformat@ git+https://github.com/EleutherAI/lm_dataformat.git@4eec05349977071bf67fc072290b95e31c8dd836->-r ./requirements/requirements.txt (line 5))
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting jsonlines (from lm_dataformat@ git+https://github.com/EleutherAI/lm_dataformat.git@4eec05349977071bf67fc072290b95e31c8dd836->-r ./requirements/requirements.txt (line 5))
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting ujson (from lm_dataformat@ git+https://github.com/EleutherAI/lm_dataformat.git@4eec05349977071bf67fc072290b95e31c8dd836->-r ./requirements/requirements.txt (line 5))
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (0.34.2)
# Collecting evaluate (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.14.0 (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2.10.1)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (0.13.2)
# Collecting pytablewriter (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading pytablewriter-1.2.0-py3-none-any.whl.metadata (37 kB)
# Collecting rouge-score>=0.0.4 (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.5.2)
# Collecting sqlitedict (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tqdm-multiprocess (from lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2.2.2)
# Collecting xxhash (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub>=0.11.0->-r ./requirements/requirements.txt (line 3))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (3.10.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r ./requirements/requirements.txt (line 15)) (2024.8.30)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (3.8.1)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_dataformat@ git+https://github.com/EleutherAI/lm_dataformat.git@4eec05349977071bf67fc072290b95e31c8dd836->-r ./requirements/requirements.txt (line 5)) (24.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (2.23.4)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (75.1.0)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading pathvalidate-3.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading tcolorpy-0.1.6-py3-none-any.whl.metadata (6.4 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6))
#   Downloading typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepspeed@ git+https://github.com/EleutherAI/DeeperSpeed.git@02e2ebf7dee6aaab3d89094ed470a4609763c742#egg=deepspeed->-r ./requirements/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.14.0->lm_eval<=0.4.1,>=0.4.0->-r ./requirements/requirements.txt (line 6)) (0.2.0)
# Downloading transformers-4.38.0-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 86.5 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
# Downloading lm_eval-0.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.9 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 22.3 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.8 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 92.4 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 39.4 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.9 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 8.7 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.5 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 27.7 MB/s eta 0:00:00
# Downloading pynvml-11.5.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.3 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 10.6 MB/s eta 0:00:00
# Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.7 MB/s eta 0:00:00
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 100.7 MB/s eta 0:00:00
# Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.0 MB/s eta 0:00:00
# Downloading pathvalidate-3.2.1-py3-none-any.whl (23 kB)
# Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.6-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.4 MB/s eta 0:00:00
# Building wheels for collected packages: deepspeed, lm_dataformat, mpi4py, rouge-score, sqlitedict
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.12.4+02e2ebf-py3-none-any.whl size=1286066 sha256=17f86adc5667eabe90d593a7e1cd0c58d2ca3d575c53878adc6631e52e2fa865
#   Stored in directory: /root/.cache/pip/wheels/ff/a3/16/4d52efba511c9490fb634597e2b4b6023819175fccfb7e4453
#   Building wheel for lm_dataformat (setup.py) ... done
#   Created wheel for lm_dataformat: filename=lm_dataformat-0.0.20-py3-none-any.whl size=5833 sha256=cfc40add9c558e1e113e3e4afa8991d9c9e79962fd99a9cc217d7668925532c6
#   Stored in directory: /root/.cache/pip/wheels/a8/5d/39/858622f394e968f5055c63d6023137b79341dfe415baf84098
#   Building wheel for mpi4py (pyproject.toml) ... done
#   Created wheel for mpi4py: filename=mpi4py-4.0.1-cp310-cp310-linux_x86_64.whl size=4266348 sha256=16754ab92e86471d0eae309cb189bca4a0f913266a87555fabda5cbad817fbb1
#   Stored in directory: /root/.cache/pip/wheels/3c/ca/13/13218a83854023ccec184e3af482f0f038b434aa32c19afee8
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=f47ef9a9e1e51b8fba1a7b35ac4d147785f51b92c1f7198c24e05e2428828664
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=e753c02a1bee039ddb90899b6a7284ee84df10ef11094e97df6de7645a2f8ecd
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built deepspeed lm_dataformat mpi4py rouge-score sqlitedict
# Installing collected packages: sqlitedict, ninja, hjson, zstandard, xxhash, ujson, tcolorpy, pynvml, pybind11, portalocker, pathvalidate, mpi4py, mbstrdecoder, jsonlines, ftfy, fsspec, dill, colorama, typepy, tqdm-multiprocess, tiktoken, sacrebleu, rouge-score, multiprocess, lm_dataformat, tokenizers, transformers, deepspeed, DataProperty, tabledata, datasets, pytablewriter, evaluate, lm_eval
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.0
#     Uninstalling transformers-4.41.0:
#       Successfully uninstalled transformers-4.41.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 datasets-3.1.0 deepspeed-0.12.4+02e2ebf dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 ftfy-6.3.1 hjson-3.1.0 jsonlines-4.0.0 lm_dataformat-0.0.20 lm_eval-0.4.1 mbstrdecoder-1.1.3 mpi4py-4.0.1 multiprocess-0.70.16 ninja-1.11.1.1 pathvalidate-3.2.1 portalocker-2.10.1 pybind11-2.13.6 pynvml-11.5.3 pytablewriter-1.2.0 rouge-score-0.1.2 sacrebleu-2.4.3 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.6 tiktoken-0.8.0 tokenizers-0.15.2 tqdm-multiprocess-0.0.11 transformers-4.38.0 typepy-1.3.2 ujson-5.10.0 xxhash-3.5.0 zstandard-0.23.0
# CPU times: user 2.5 s, sys: 410 ms, total: 2.91 s
# Wall time: 7min 12s

# %% [markdown]
# # Preparing Custom Dataset

# %%
# %cd /content/gpt-neox
# !!mkdir -p data
# Out:
# /content/gpt-neox
# []

# %%
import json

# Generate a list of dictionaries
lines = []
with open("/content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion/train.txt", encoding="utf8") as f:
    for line in f.read().splitlines():
        if line:
            lines.append({"text": line})

# Convert to a list of JSON strings
json_lines = [json.dumps(l) for l in lines]

# Join lines and save to .jsonl file
json_data = '\n'.join(json_lines)
with open('/content/gpt-neox/data/py95K_train.jsonl', 'w') as f:
    f.write(json_data)

# %% [markdown]
# # Using Byte-Pair Encoding Tokenizer

# %%
# %cd data
# !wget https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json
# !wget https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt
# Out:
# /content/gpt-neox/data
# --2024-11-05 19:55:22--  https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.73.216, 52.216.166.29, 3.5.2.19, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.73.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1042301 (1018K) [application/json]
# Saving to: ‘gpt2-vocab.json’
#
# gpt2-vocab.json     100%[===================>]   1018K  2.68MB/s    in 0.4s
#
# 2024-11-05 19:55:23 (2.68 MB/s) - ‘gpt2-vocab.json’ saved [1042301/1042301]
#
# --2024-11-05 19:55:23--  https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.73.216, 52.216.166.29, 3.5.2.19, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.73.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456318 (446K) [text/plain]
# Saving to: ‘gpt2-merges.txt’
#
# gpt2-merges.txt     100%[===================>] 445.62K  1.76MB/s    in 0.2s
#
# 2024-11-05 19:55:24 (1.76 MB/s) - ‘gpt2-merges.txt’ saved [456318/456318]

# %%
# %cd /content/GPT-NeoX-Colab/data
# !tar -xf py150_processed.tar.gz
# !mkdir -p /content/gpt-neox/processed_data
# !cp py150_processed/* /content/gpt-neox/processed_data
# %cd /content
# Out:
# /content/GPT-NeoX-Colab/data
# /content

# %%
# %%time
import os

# Define the file path you want to check for existence
file_path = "/content/gpt-neox/processed_data"

# Check if the file exists
if not os.path.exists(file_path):
  # %cd /content/gpt-neox
  # !mkdir -p processed_data
  # !python tools/datasets/preprocess_data.py \
    --input ./data/py95K_train.jsonl \
    --vocab ./data/gpt2-vocab.json \
    --merge-file ./data/gpt2-merges.txt \
    --output-prefix ./processed_data/py150 \
    --tokenizer-type GPT2BPETokenizer \
    --dataset-impl mmap \
    --append-eod
else:
    print("File already exists, skipping download and preprocessing.")
# Out:
# File already exists, skipping download and preprocessing.
# CPU times: user 713 µs, sys: 3 µs, total: 716 µs
# Wall time: 722 µs

# %% [markdown]
# # Tokens count in Dataset

# %%
from transformers import GPT2Tokenizer

# Initialize the GPT-2 tokenizer (BPE-based)
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Path to your text file
file_path = "/content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion/train.txt"

# Initialize a token counter
total_token_count = 0

# Open the file and read line by line to count tokens
with open(file_path, "r", encoding="utf-8") as file:
   for line in file:
       tokens = tokenizer.encode(line)
       total_token_count += len(tokens)

print(f"Total token count: {total_token_count}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3814 > 1024). Running this sequence through the model will result in indexing errors
# Total token count: 182707377

# %% [markdown]
# # Training

# %%
# %load_ext tensorboard

# %%
# %%time
# %cd /content/gpt-neox
# !python ./deepy.py train.py --conf_dir /content/GPT-NeoX-Colab/configs CC19M.yml cc_setup.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# [2024-11-05 20:15:51,389] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.63 | bwd: 359.00 | bwd_inner: 353.84 | bwd_allreduce: 5.07 | step: 36.18
# [2024-11-05 20:15:51,920] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.06 | msg size: 134.33 MB | algbw (Gbps): 40921.92 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,928] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,936] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,939] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,957] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 15033.25 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,957] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.68 | busbw (Gbps): 0.00
# [2024-11-05 20:15:51,958] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.75 | optimizer_gradients: 5.88 | optimizer_step: 11.87
# [2024-11-05 20:15:51,958] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.51 | bwd_microstep: 363.00 | bwd_inner_microstep: 357.88 | bwd_allreduce_microstep: 5.07 | step_microstep: 36.23
# [2024-11-05 20:15:51,959] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.48 | bwd: 362.99 | bwd_inner: 357.87 | bwd_allreduce: 5.07 | step: 36.24
# [2024-11-05 20:15:52,482] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.04 | msg size: 134.33 MB | algbw (Gbps): 55150.06 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,490] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,498] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,501] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,519] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14688.16 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,519] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.56 | busbw (Gbps): 0.00
# [2024-11-05 20:15:52,521] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.81 | optimizer_gradients: 5.88 | optimizer_step: 11.87
# [2024-11-05 20:15:52,521] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.20 | bwd_microstep: 355.53 | bwd_inner_microstep: 350.51 | bwd_allreduce_microstep: 4.97 | step_microstep: 37.43
# [2024-11-05 20:15:52,521] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.14 | bwd: 355.52 | bwd_inner: 350.50 | bwd_allreduce: 4.97 | step: 37.43
# [2024-11-05 20:15:53,047] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 46333.30 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,055] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,062] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,065] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,083] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 16584.75 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,083] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.13 | msg size: 80.0 KB | algbw (Gbps): 4.92 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,085] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.71 | optimizer_gradients: 5.90 | optimizer_step: 11.85
# [2024-11-05 20:15:53,085] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 99.85 | bwd_microstep: 358.91 | bwd_inner_microstep: 353.79 | bwd_allreduce_microstep: 5.08 | step_microstep: 36.52
# [2024-11-05 20:15:53,085] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 99.83 | bwd: 358.90 | bwd_inner: 353.78 | bwd_allreduce: 5.08 | step: 36.54
# [2024-11-05 20:15:53,610] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 31203.64 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,618] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,625] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.20 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,628] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,647] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 18961.65 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,647] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.15 | msg size: 80.0 KB | algbw (Gbps): 4.42 | busbw (Gbps): 0.00
# [2024-11-05 20:15:53,648] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.71 | optimizer_gradients: 5.89 | optimizer_step: 11.87
# [2024-11-05 20:15:53,648] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.83 | bwd_microstep: 356.67 | bwd_inner_microstep: 351.65 | bwd_allreduce_microstep: 4.98 | step_microstep: 36.70
# [2024-11-05 20:15:53,649] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.80 | bwd: 356.66 | bwd_inner: 351.64 | bwd_allreduce: 4.98 | step: 36.71
# [2024-11-05 20:15:54,176] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 34220.90 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,184] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.28 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,193] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,196] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,214] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 16806.51 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,215] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.33 | msg size: 80.0 KB | algbw (Gbps): 1.99 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,215] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.93 | optimizer_gradients: 5.89 | optimizer_step: 11.88
# [2024-11-05 20:15:54,216] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 102.75 | bwd_microstep: 357.01 | bwd_inner_microstep: 351.93 | bwd_allreduce_microstep: 5.04 | step_microstep: 38.13
# [2024-11-05 20:15:54,216] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 102.72 | bwd: 357.00 | bwd_inner: 351.92 | bwd_allreduce: 5.04 | step: 38.13
# [2024-11-05 20:15:54,745] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.10 | msg size: 134.33 MB | algbw (Gbps): 23514.73 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,755] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,763] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,767] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,785] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14219.33 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,785] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.64 | busbw (Gbps): 0.00
# [2024-11-05 20:15:54,786] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.73 | optimizer_gradients: 5.91 | optimizer_step: 11.90
# [2024-11-05 20:15:54,787] [INFO] [logging.py:96:log_dist] [Rank 0] step=480, skipped=0, lr=[0.0005856624805855548, 0.0005856624805855548], mom=[[0.9, 0.95], [0.9, 0.95]]
# [2024-11-05 20:15:54,787] [INFO] [timer.py:260:stop] epoch=0/micro_step=480/global_step=480, RunningAvgSamplesPerSec=7.225132939432279, CurrSamplesPerSec=7.050524254382094, MemAllocated=0.93GB, MaxMemAllocated=3.31GB
# [2024-11-05 20:15:54,787] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.76 | bwd_microstep: 359.54 | bwd_inner_microstep: 353.65 | bwd_allreduce_microstep: 5.84 | step_microstep: 40.41
# [2024-11-05 20:15:54,788] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.74 | bwd: 359.52 | bwd_inner: 353.64 | bwd_allreduce: 5.84 | step: 40.41
#  samples/sec: 7.017 | iteration      480/    1000 | elapsed time per iteration (ms): 570.1 | learning rate: 5.857E-04 | approx flops per GPU: 5.8TFLOPS | lm_loss: 2.189762E+00 | loss scale: 4096.0 | number of skipped iterations:   0 | number of nan iterations:   0 |
# time (ms) | forward: 169.42 | backward: 360.26 | backward-backward: 360.22 | backward-allreduce: 0.00 | optimizer: 38.75 | batch generator: 2.75
# [2024-11-05 20:15:55,319] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.45 | msg size: 134.33 MB | algbw (Gbps): 4984.54 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,328] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,335] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,338] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,356] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 15732.16 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,357] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.71 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,358] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.72 | optimizer_gradients: 5.89 | optimizer_step: 11.88
# [2024-11-05 20:15:55,358] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.43 | bwd_microstep: 361.86 | bwd_inner_microstep: 355.82 | bwd_allreduce_microstep: 5.99 | step_microstep: 37.02
# [2024-11-05 20:15:55,358] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.40 | bwd: 361.83 | bwd_inner: 355.81 | bwd_allreduce: 5.99 | step: 37.02
# [2024-11-05 20:15:55,887] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 32041.23 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,895] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,903] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,905] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,923] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 15662.14 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,924] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.66 | busbw (Gbps): 0.00
# [2024-11-05 20:15:55,925] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.75 | optimizer_gradients: 5.88 | optimizer_step: 11.86
# [2024-11-05 20:15:55,925] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 99.87 | bwd_microstep: 361.71 | bwd_inner_microstep: 356.49 | bwd_allreduce_microstep: 5.14 | step_microstep: 36.14
# [2024-11-05 20:15:55,925] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 99.84 | bwd: 361.67 | bwd_inner: 356.47 | bwd_allreduce: 5.14 | step: 36.15
# [2024-11-05 20:15:56,450] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.06 | msg size: 134.33 MB | algbw (Gbps): 36757.11 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,458] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,466] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,468] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,486] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14956.58 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,487] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.82 | busbw (Gbps): 0.00
# [2024-11-05 20:15:56,488] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.76 | optimizer_gradients: 5.87 | optimizer_step: 11.85
# [2024-11-05 20:15:56,488] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.03 | bwd_microstep: 357.73 | bwd_inner_microstep: 352.64 | bwd_allreduce_microstep: 5.05 | step_microstep: 36.20
# [2024-11-05 20:15:56,488] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.00 | bwd: 357.71 | bwd_inner: 352.63 | bwd_allreduce: 5.05 | step: 36.20
# [2024-11-05 20:15:57,015] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 42146.39 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,023] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,031] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,034] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,052] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 20366.22 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,053] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.77 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,054] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.69 | optimizer_gradients: 5.88 | optimizer_step: 11.86
# [2024-11-05 20:15:57,054] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.18 | bwd_microstep: 359.84 | bwd_inner_microstep: 354.73 | bwd_allreduce_microstep: 5.07 | step_microstep: 37.18
# [2024-11-05 20:15:57,055] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.16 | bwd: 359.83 | bwd_inner: 354.72 | bwd_allreduce: 5.07 | step: 37.19
# [2024-11-05 20:15:57,579] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 31738.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,587] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,595] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,598] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,616] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 18253.54 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,616] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.16 | msg size: 80.0 KB | algbw (Gbps): 4.09 | busbw (Gbps): 0.00
# [2024-11-05 20:15:57,617] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.71 | optimizer_gradients: 5.89 | optimizer_step: 11.89
# [2024-11-05 20:15:57,617] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.95 | bwd_microstep: 356.58 | bwd_inner_microstep: 351.50 | bwd_allreduce_microstep: 5.03 | step_microstep: 36.16
# [2024-11-05 20:15:57,618] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.93 | bwd: 356.57 | bwd_inner: 351.49 | bwd_allreduce: 5.03 | step: 36.16
# [2024-11-05 20:15:58,147] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 32832.92 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,155] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,163] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,166] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,184] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 17001.37 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,185] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.78 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,186] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.71 | optimizer_gradients: 5.90 | optimizer_step: 11.87
# [2024-11-05 20:15:58,186] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.43 | bwd_microstep: 361.81 | bwd_inner_microstep: 356.73 | bwd_allreduce_microstep: 5.03 | step_microstep: 36.63
# [2024-11-05 20:15:58,186] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.40 | bwd: 361.79 | bwd_inner: 356.72 | bwd_allreduce: 5.03 | step: 36.64
# [2024-11-05 20:15:58,713] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 33235.78 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,721] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,728] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,731] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,749] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 15241.59 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,750] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.71 | busbw (Gbps): 0.00
# [2024-11-05 20:15:58,751] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.71 | optimizer_gradients: 5.90 | optimizer_step: 11.89
# [2024-11-05 20:15:58,751] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.57 | bwd_microstep: 357.50 | bwd_inner_microstep: 352.40 | bwd_allreduce_microstep: 5.05 | step_microstep: 36.07
# [2024-11-05 20:15:58,751] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.55 | bwd: 357.48 | bwd_inner: 352.39 | bwd_allreduce: 5.05 | step: 36.08
# [2024-11-05 20:15:59,282] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 31426.43 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,290] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,298] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,300] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,319] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.04 | msg size: 134.25 MB | algbw (Gbps): 28989.15 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,319] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.15 | msg size: 80.0 KB | algbw (Gbps): 4.52 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,320] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.67 | optimizer_gradients: 5.89 | optimizer_step: 11.87
# [2024-11-05 20:15:59,320] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 102.50 | bwd_microstep: 360.79 | bwd_inner_microstep: 355.73 | bwd_allreduce_microstep: 5.02 | step_microstep: 36.11
# [2024-11-05 20:15:59,321] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 102.47 | bwd: 360.78 | bwd_inner: 355.72 | bwd_allreduce: 5.02 | step: 36.11
# [2024-11-05 20:15:59,847] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.08 | msg size: 134.33 MB | algbw (Gbps): 28769.05 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,855] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,862] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,869] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.20 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,887] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14179.22 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,888] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.71 | busbw (Gbps): 0.00
# [2024-11-05 20:15:59,889] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.72 | optimizer_gradients: 6.10 | optimizer_step: 11.88
# [2024-11-05 20:15:59,889] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.28 | bwd_microstep: 358.56 | bwd_inner_microstep: 353.35 | bwd_allreduce_microstep: 5.17 | step_microstep: 40.04
# [2024-11-05 20:15:59,889] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.25 | bwd: 358.55 | bwd_inner: 353.34 | bwd_allreduce: 5.17 | step: 40.04
# [2024-11-05 20:16:00,418] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 41598.72 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,426] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,433] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,436] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,455] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14248.11 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,455] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.56 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,456] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.92 | optimizer_gradients: 5.89 | optimizer_step: 11.86
# [2024-11-05 20:16:00,456] [INFO] [logging.py:96:log_dist] [Rank 0] step=490, skipped=0, lr=[0.0005714118621206842, 0.0005714118621206842], mom=[[0.9, 0.95], [0.9, 0.95]]
# [2024-11-05 20:16:00,457] [INFO] [timer.py:260:stop] epoch=0/micro_step=490/global_step=490, RunningAvgSamplesPerSec=7.222591917255806, CurrSamplesPerSec=7.098711738131697, MemAllocated=0.93GB, MaxMemAllocated=3.31GB
# [2024-11-05 20:16:00,457] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.60 | bwd_microstep: 359.39 | bwd_inner_microstep: 354.19 | bwd_allreduce_microstep: 5.16 | step_microstep: 36.93
# [2024-11-05 20:16:00,457] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.57 | bwd: 359.38 | bwd_inner: 354.18 | bwd_allreduce: 5.16 | step: 36.94
#  samples/sec: 7.055 | iteration      490/    1000 | elapsed time per iteration (ms): 567.0 | learning rate: 5.714E-04 | approx flops per GPU: 5.9TFLOPS | lm_loss: 2.306225E+00 | loss scale: 4096.0 | number of skipped iterations:   0 | number of nan iterations:   0 |
# time (ms) | forward: 168.34 | backward: 359.80 | backward-backward: 359.76 | backward-allreduce: 0.00 | optimizer: 37.36 | batch generator: 1.59
# [2024-11-05 20:16:00,987] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.06 | msg size: 134.33 MB | algbw (Gbps): 40756.15 | busbw (Gbps): 0.00
# [2024-11-05 20:16:00,995] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,003] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,005] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,024] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 19231.06 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,024] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.17 | msg size: 80.0 KB | algbw (Gbps): 3.91 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,025] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.87 | optimizer_gradients: 5.90 | optimizer_step: 11.86
# [2024-11-05 20:16:01,025] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.99 | bwd_microstep: 360.44 | bwd_inner_microstep: 355.12 | bwd_allreduce_microstep: 5.27 | step_microstep: 36.31
# [2024-11-05 20:16:01,026] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.95 | bwd: 360.42 | bwd_inner: 355.11 | bwd_allreduce: 5.27 | step: 36.31
# [2024-11-05 20:16:01,558] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.09 | msg size: 134.33 MB | algbw (Gbps): 23760.67 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,568] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.24 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,576] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,580] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,598] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12506.34 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,599] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.17 | msg size: 80.0 KB | algbw (Gbps): 3.92 | busbw (Gbps): 0.00
# [2024-11-05 20:16:01,600] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.94 | optimizer_gradients: 5.92 | optimizer_step: 11.86
# [2024-11-05 20:16:01,600] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.57 | bwd_microstep: 363.48 | bwd_inner_microstep: 357.64 | bwd_allreduce_microstep: 5.79 | step_microstep: 40.12
# [2024-11-05 20:16:01,601] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.54 | bwd: 363.46 | bwd_inner: 357.63 | bwd_allreduce: 5.79 | step: 40.12
# [2024-11-05 20:16:02,133] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.08 | msg size: 134.33 MB | algbw (Gbps): 28593.84 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,142] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,151] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,155] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,173] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12383.12 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,174] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.19 | msg size: 80.0 KB | algbw (Gbps): 3.40 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,175] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.90 | optimizer_gradients: 5.95 | optimizer_step: 11.89
# [2024-11-05 20:16:02,175] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.72 | bwd_microstep: 362.31 | bwd_inner_microstep: 356.48 | bwd_allreduce_microstep: 5.76 | step_microstep: 40.07
# [2024-11-05 20:16:02,176] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.70 | bwd: 362.28 | bwd_inner: 356.47 | bwd_allreduce: 5.76 | step: 40.07
# [2024-11-05 20:16:02,712] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.12 | msg size: 134.33 MB | algbw (Gbps): 19332.04 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,722] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.23 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,730] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.22 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,734] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,752] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12816.04 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,753] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.17 | msg size: 80.0 KB | algbw (Gbps): 3.90 | busbw (Gbps): 0.00
# [2024-11-05 20:16:02,754] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.91 | optimizer_gradients: 5.87 | optimizer_step: 11.86
# [2024-11-05 20:16:02,755] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 99.68 | bwd_microstep: 366.70 | bwd_inner_microstep: 360.40 | bwd_allreduce_microstep: 6.18 | step_microstep: 40.26
# [2024-11-05 20:16:02,755] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 99.66 | bwd: 366.67 | bwd_inner: 360.40 | bwd_allreduce: 6.16 | step: 40.27
# [2024-11-05 20:16:03,288] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.11 | msg size: 134.33 MB | algbw (Gbps): 21270.50 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,297] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.33 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,305] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,312] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,330] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12418.08 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,330] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.19 | msg size: 80.0 KB | algbw (Gbps): 3.52 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,332] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.97 | optimizer_gradients: 5.97 | optimizer_step: 11.87
# [2024-11-05 20:16:03,332] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.27 | bwd_microstep: 361.98 | bwd_inner_microstep: 355.68 | bwd_allreduce_microstep: 6.16 | step_microstep: 42.37
# [2024-11-05 20:16:03,333] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.25 | bwd: 361.95 | bwd_inner: 355.70 | bwd_allreduce: 6.14 | step: 42.38
# [2024-11-05 20:16:03,868] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 31440.46 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,877] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.22 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,885] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,889] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,908] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 13340.72 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,908] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.18 | msg size: 80.0 KB | algbw (Gbps): 3.56 | busbw (Gbps): 0.00
# [2024-11-05 20:16:03,909] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.92 | optimizer_gradients: 5.90 | optimizer_step: 11.86
# [2024-11-05 20:16:03,910] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 102.45 | bwd_microstep: 362.32 | bwd_inner_microstep: 356.54 | bwd_allreduce_microstep: 5.71 | step_microstep: 40.01
# [2024-11-05 20:16:03,910] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 102.42 | bwd: 362.29 | bwd_inner: 356.52 | bwd_allreduce: 5.71 | step: 40.20
# [2024-11-05 20:16:04,442] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.09 | msg size: 134.33 MB | algbw (Gbps): 24176.66 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,451] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.23 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,460] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,464] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,482] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 13092.57 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,483] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.39 | msg size: 80.0 KB | algbw (Gbps): 1.69 | busbw (Gbps): 0.00
# [2024-11-05 20:16:04,484] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 1.13 | optimizer_gradients: 5.94 | optimizer_step: 11.87
# [2024-11-05 20:16:04,485] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.23 | bwd_microstep: 359.79 | bwd_inner_microstep: 353.85 | bwd_allreduce_microstep: 5.88 | step_microstep: 41.18
# [2024-11-05 20:16:04,485] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.21 | bwd: 359.77 | bwd_inner: 353.83 | bwd_allreduce: 5.88 | step: 41.19
# [2024-11-05 20:16:05,022] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 34154.52 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,031] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.22 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,039] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,043] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,061] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12497.45 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,062] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.18 | msg size: 80.0 KB | algbw (Gbps): 3.72 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,063] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.90 | optimizer_gradients: 5.90 | optimizer_step: 11.83
# [2024-11-05 20:16:05,064] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 103.19 | bwd_microstep: 362.38 | bwd_inner_microstep: 356.53 | bwd_allreduce_microstep: 5.78 | step_microstep: 39.84
# [2024-11-05 20:16:05,064] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 103.16 | bwd: 362.36 | bwd_inner: 356.51 | bwd_allreduce: 5.79 | step: 39.85
# [2024-11-05 20:16:05,596] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 32894.27 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,609] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.23 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,617] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,621] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.21 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,639] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 12604.88 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,640] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.18 | msg size: 80.0 KB | algbw (Gbps): 3.62 | busbw (Gbps): 0.00
# [2024-11-05 20:16:05,641] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.92 | optimizer_gradients: 5.96 | optimizer_step: 11.90
# [2024-11-05 20:16:05,642] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.34 | bwd_microstep: 360.24 | bwd_inner_microstep: 350.62 | bwd_allreduce_microstep: 9.49 | step_microstep: 39.97
# [2024-11-05 20:16:05,642] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.31 | bwd: 360.22 | bwd_inner: 350.60 | bwd_allreduce: 9.52 | step: 39.98
# [2024-11-05 20:16:06,179] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 30083.99 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,192] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.23 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,201] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,205] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,223] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 13034.38 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,224] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.18 | msg size: 80.0 KB | algbw (Gbps): 3.56 | busbw (Gbps): 0.00
# [2024-11-05 20:16:06,225] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.93 | optimizer_gradients: 5.93 | optimizer_step: 11.96
# [2024-11-05 20:16:06,225] [INFO] [logging.py:96:log_dist] [Rank 0] step=500, skipped=0, lr=[0.0005571396837256635, 0.0005571396837256635], mom=[[0.9, 0.95], [0.9, 0.95]]
# [2024-11-05 20:16:06,226] [INFO] [timer.py:260:stop] epoch=0/micro_step=500/global_step=500, RunningAvgSamplesPerSec=7.21828617940868, CurrSamplesPerSec=6.924758965604488, MemAllocated=0.93GB, MaxMemAllocated=3.31GB
# [2024-11-05 20:16:06,226] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 99.62 | bwd_microstep: 370.61 | bwd_inner_microstep: 360.50 | bwd_allreduce_microstep: 10.05 | step_microstep: 41.44
# [2024-11-05 20:16:06,227] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 99.59 | bwd: 370.59 | bwd_inner: 360.48 | bwd_allreduce: 10.05 | step: 41.44
#  samples/sec: 6.932 | iteration      500/    1000 | elapsed time per iteration (ms): 577.0 | learning rate: 5.571E-04 | approx flops per GPU: 5.8TFLOPS | lm_loss: 2.224714E+00 | loss scale: 4096.0 | number of skipped iterations:   0 | number of nan iterations:   0 |
# time (ms) | forward: 170.61 | backward: 363.29 | backward-backward: 363.24 | backward-allreduce: 0.00 | optimizer: 40.83 | batch generator: 3.56
# --------------------------------------------------------------------------------------------------------
#  validation results at iteration 500 | lm_loss value: 2.060323E+00 | lm_loss_ppl value: 7.848506E+00 |
# --------------------------------------------------------------------------------------------------------
# [2024-11-05 20:16:24,171] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.07 | msg size: 134.33 MB | algbw (Gbps): 32320.62 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,180] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.23 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,188] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.20 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,193] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.19 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,211] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.09 | msg size: 134.25 MB | algbw (Gbps): 13092.57 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,211] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.19 | msg size: 80.0 KB | algbw (Gbps): 3.37 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,213] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.94 | optimizer_gradients: 5.94 | optimizer_step: 11.88
# [2024-11-05 20:16:24,216] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 10643.32 | bwd_microstep: 366.85 | bwd_inner_microstep: 360.91 | bwd_allreduce_microstep: 5.86 | step_microstep: 40.15
# [2024-11-05 20:16:24,218] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 10640.87 | bwd: 366.82 | bwd_inner: 360.89 | bwd_allreduce: 5.86 | step: 40.16
# [2024-11-05 20:16:24,745] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.04 | msg size: 134.33 MB | algbw (Gbps): 53032.10 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,753] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,760] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,763] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,781] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 19715.87 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,782] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.78 | busbw (Gbps): 0.00
# [2024-11-05 20:16:24,783] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.85 | optimizer_gradients: 5.91 | optimizer_step: 11.88
# [2024-11-05 20:16:24,783] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 99.21 | bwd_microstep: 355.88 | bwd_inner_microstep: 350.54 | bwd_allreduce_microstep: 5.28 | step_microstep: 36.42
# [2024-11-05 20:16:24,784] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 99.18 | bwd: 355.86 | bwd_inner: 350.52 | bwd_allreduce: 5.28 | step: 36.42
# [2024-11-05 20:16:25,318] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.04 | msg size: 134.33 MB | algbw (Gbps): 52952.35 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,326] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,333] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,336] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,354] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.07 | msg size: 134.25 MB | algbw (Gbps): 15274.67 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,354] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.64 | busbw (Gbps): 0.00
# [2024-11-05 20:16:25,355] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.73 | optimizer_gradients: 5.87 | optimizer_step: 11.85
# ...
# [2024-11-05 20:21:05,738] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.22 | bwd: 361.45 | bwd_inner: 356.34 | bwd_allreduce: 5.07 | step: 36.52
# [2024-11-05 20:21:06,264] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.04 | msg size: 134.33 MB | algbw (Gbps): 52284.06 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,272] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,279] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,282] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.15 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,300] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14271.22 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,301] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.17 | msg size: 80.0 KB | algbw (Gbps): 3.76 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,302] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.87 | optimizer_gradients: 5.90 | optimizer_step: 11.86
# [2024-11-05 20:21:06,302] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.04 | bwd_microstep: 357.98 | bwd_inner_microstep: 352.74 | bwd_allreduce_microstep: 5.20 | step_microstep: 36.39
# [2024-11-05 20:21:06,303] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.02 | bwd: 357.97 | bwd_inner: 352.73 | bwd_allreduce: 5.20 | step: 36.39
# [2024-11-05 20:21:06,832] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.04 | msg size: 134.33 MB | algbw (Gbps): 51594.60 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,840] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,848] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,851] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,869] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 17422.19 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,869] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.85 | busbw (Gbps): 0.00
# [2024-11-05 20:21:06,870] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.73 | optimizer_gradients: 5.89 | optimizer_step: 11.85
# [2024-11-05 20:21:06,871] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.78 | bwd_microstep: 360.30 | bwd_inner_microstep: 355.21 | bwd_allreduce_microstep: 5.05 | step_microstep: 36.56
# [2024-11-05 20:21:06,871] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.76 | bwd: 360.28 | bwd_inner: 355.20 | bwd_allreduce: 5.05 | step: 36.57
# [2024-11-05 20:21:07,397] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 44545.62 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,405] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,412] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,415] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,434] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 19551.57 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,434] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.82 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,435] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.70 | optimizer_gradients: 5.89 | optimizer_step: 11.88
# [2024-11-05 20:21:07,435] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 100.10 | bwd_microstep: 358.58 | bwd_inner_microstep: 353.49 | bwd_allreduce_microstep: 5.02 | step_microstep: 36.53
# [2024-11-05 20:21:07,436] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.08 | bwd: 358.55 | bwd_inner: 353.48 | bwd_allreduce: 5.02 | step: 36.54
# [2024-11-05 20:21:07,966] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 49983.41 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,974] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.16 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,982] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:07,985] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,003] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.08 | msg size: 134.25 MB | algbw (Gbps): 14924.86 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,003] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.14 | msg size: 80.0 KB | algbw (Gbps): 4.78 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,004] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.74 | optimizer_gradients: 5.89 | optimizer_step: 11.85
# [2024-11-05 20:21:08,005] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.96 | bwd_microstep: 361.36 | bwd_inner_microstep: 356.12 | bwd_allreduce_microstep: 5.19 | step_microstep: 36.50
# [2024-11-05 20:21:08,005] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.94 | bwd: 361.34 | bwd_inner: 356.11 | bwd_allreduce: 5.19 | step: 36.50
# [2024-11-05 20:21:08,531] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.05 | msg size: 134.33 MB | algbw (Gbps): 43716.09 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,539] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,547] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.14 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,550] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,568] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.06 | msg size: 134.25 MB | algbw (Gbps): 18829.77 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,568] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.17 | msg size: 80.0 KB | algbw (Gbps): 3.92 | busbw (Gbps): 0.00
# [2024-11-05 20:21:08,569] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.76 | optimizer_gradients: 5.93 | optimizer_step: 11.86
# [2024-11-05 20:21:08,570] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.45 | bwd_microstep: 357.65 | bwd_inner_microstep: 352.53 | bwd_allreduce_microstep: 5.07 | step_microstep: 36.36
# [2024-11-05 20:21:08,570] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 101.43 | bwd: 357.63 | bwd_inner: 352.52 | bwd_allreduce: 5.07 | step: 36.36
# [2024-11-05 20:21:09,101] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.09 | msg size: 134.33 MB | algbw (Gbps): 24293.42 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,116] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.48 | msg size: 1.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,124] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.26 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,133] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.26 | msg size: 4.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,152] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.10 | msg size: 134.25 MB | algbw (Gbps): 11793.84 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,152] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_gather_into_tensor | time (ms): 0.18 | msg size: 80.0 KB | algbw (Gbps): 3.60 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,154] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | optimizer_allgather: 1.20 | optimizer_gradients: 5.98 | optimizer_step: 11.93
# [2024-11-05 20:21:09,154] [INFO] [logging.py:96:log_dist] [Rank 0] step=1000, skipped=0, lr=[0.0001, 0.0001], mom=[[0.9, 0.95], [0.9, 0.95]]
# [2024-11-05 20:21:09,155] [INFO] [timer.py:260:stop] epoch=0/micro_step=1000/global_step=1000, RunningAvgSamplesPerSec=7.1427001283774, CurrSamplesPerSec=6.893826494930677, MemAllocated=0.93GB, MaxMemAllocated=3.31GB
# [2024-11-05 20:21:09,155] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd_microstep: 101.02 | bwd_microstep: 361.86 | bwd_inner_microstep: 355.75 | bwd_allreduce_microstep: 6.01 | step_microstep: 52.40
# [2024-11-05 20:21:09,156] [INFO] [logging.py:96:log_dist] [Rank 0] time (ms) | fwd: 100.99 | bwd: 361.86 | bwd_inner: 355.74 | bwd_allreduce: 6.04 | step: 52.41
#  samples/sec: 7.026 | iteration     1000/    1000 | elapsed time per iteration (ms): 569.3 | learning rate: 1.000E-04 | approx flops per GPU: 5.8TFLOPS | lm_loss: 2.006398E+00 | loss scale: 8192.0 | number of skipped iterations:   0 | number of nan iterations:   0 |
# time (ms) | forward: 168.82 | backward: 359.95 | backward-backward: 359.91 | backward-allreduce: 0.00 | optimizer: 38.73 | batch generator: 1.63
# [2024-11-05 20:21:09,162] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.33 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,163] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint global_step1000 is about to be saved!
# [2024-11-05 20:21:09,163] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.18 | msg size: 20.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,165] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.17 | msg size: 20.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1898: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# [2024-11-05 20:21:09,233] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: checkpoints/global_step1000/mp_rank_00_model_states.pt
# [2024-11-05 20:21:09,233] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving checkpoints/global_step1000/mp_rank_00_model_states.pt...
# [2024-11-05 20:21:09,786] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved checkpoints/global_step1000/mp_rank_00_model_states.pt.
# [2024-11-05 20:21:09,787] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.48 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:09,789] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2024-11-05 20:21:16,624] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2024-11-05 20:21:16,629] [INFO] [engine.py:3426:_save_zero_checkpoint] zero checkpoint saved checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2024-11-05 20:21:16,629] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint global_step1000 is ready now!
# [2024-11-05 20:21:16,630] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.34 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# ---------------------------------------------------------------------------------------------------------
#  validation results at iteration 1000 | lm_loss value: 1.876806E+00 | lm_loss_ppl value: 6.532604E+00 |
# ---------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------
#  validation results at the end of training for val data | lm_loss value: 1.872159E+00 | lm_loss_ppl value: 6.502318E+00 |
# ---------------------------------------------------------------------------------------------------------------------------
# [2024-11-05 20:21:51,723] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.28 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:51,723] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint global_step1000 is about to be saved!
# [2024-11-05 20:21:51,725] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.24 | msg size: 20.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:51,725] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: all_reduce | time (ms): 0.24 | msg size: 20.0 B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:51,728] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: checkpoints/global_step1000/mp_rank_00_model_states.pt
# [2024-11-05 20:21:51,729] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving checkpoints/global_step1000/mp_rank_00_model_states.pt...
# [2024-11-05 20:21:52,128] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved checkpoints/global_step1000/mp_rank_00_model_states.pt.
# [2024-11-05 20:21:52,129] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.49 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# [2024-11-05 20:21:52,130] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2024-11-05 20:22:04,166] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2024-11-05 20:22:04,168] [INFO] [engine.py:3426:_save_zero_checkpoint] zero checkpoint saved checkpoints/global_step1000/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2024-11-05 20:22:04,168] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint global_step1000 is ready now!
# [2024-11-05 20:22:04,169] [INFO] [logging.py:96:log_dist] [Rank 0] comm op: barrier | time (ms): 0.47 | msg size: 0B | algbw (Gbps): 0.00 | busbw (Gbps): 0.00
# Evaluating iter 10/100
# Evaluating iter 20/100
# Evaluating iter 30/100
# Evaluating iter 40/100
# Evaluating iter 50/100
# Evaluating iter 60/100
# Evaluating iter 70/100
# Evaluating iter 80/100
# Evaluating iter 90/100
# Evaluating iter 100/100
# ----------------------------------------------------------------------------------------------------------------------
#  test results at the end of training for test data | lm_loss value: 1.918597E+00 | lm_loss_ppl value: 6.811398E+00 |
# ----------------------------------------------------------------------------------------------------------------------
# [2024-11-05 20:22:25,372] [INFO] [launch.py:347:main] Process 8334 exits successfully.
# CPU times: user 4.77 s, sys: 524 ms, total: 5.29 s
# Wall time: 12min 30s

# %%
# !pip show datasets
# !pip install datasets==1.18.0
# !pip install hf-transfer
# !pip install lm-eval --upgrade

# %% [markdown]
# # Inference

# %%
# %cd /content/gpt-neox

import tensorflow as tf
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator
import os
import numpy as np
# Path to the latest log file
log_dir = "tensorboard"
log_files = [os.path.join(log_dir, d) for d in os.listdir(log_dir)]
latest_log_dir = max(log_files, key=os.path.getmtime)

# Initialize EventAccumulator to load scalar data
ea = event_accumulator.EventAccumulator(latest_log_dir)
ea.Reload()  # Load all logs

# List all scalar keys available in the logs
scalar_keys = ea.Tags()['scalars']
print("Available scalar keys:", scalar_keys)

# Extract training and validation losses
train_loss = ea.Scalars('train/lm_loss')  # Adjust for actual name if necessary
val_loss = ea.Scalars('validation/lm_loss')  # Adjust for actual name if necessary

# Convert to lists for plotting
train_loss_values = [x.value for x in train_loss]
val_loss_values = [x.value for x in val_loss]

# Find the lengths of both arrays
len_train = len(train_loss_values)
len_val = len(val_loss_values)

iterations = None
# Interpolate the shorter array
if len_train != len_val:
    if len_train > len_val:
        # Interpolate validation loss to match the training loss length
        iterations = np.linspace(1, len_train, len_train)
        val_iterations = np.linspace(1, len_train, len_val)
        val_loss_values = np.interp(iterations, val_iterations, val_loss_values)
    else:
        # Interpolate training loss to match the validation loss length
        iterations = np.linspace(1, len_val, len_val)
        train_iterations = np.linspace(1, len_val, len_train)
        train_loss_values = np.interp(iterations, train_iterations, train_loss_values)
else:
    iterations = range(1, len_train + 1)

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(iterations, train_loss_values, label='Training Loss')
plt.plot(iterations, val_loss_values, label='Validation Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# /content/gpt-neox
# Available scalar keys: ['timers/forward', 'timers/backward', 'timers/backward-backward', 'timers/backward-allreduce', 'timers/optimizer', 'timers/batch generator', 'train/learning_rate', 'train/lm_loss', 'train/loss_scale', 'runtime/samples_per_sec', 'runtime/iteration_time', 'runtime/flops_per_sec_per_gpu', 'validation/lm_loss', 'validation/lm_loss_ppl', 'test/lm_loss', 'test/lm_loss_ppl']

# %% [markdown]
# # HuggingFace Inference

# %% [markdown]
# # Convert Our Model to HuggingFace Format

# %%
import os

# Define the path to the checkpoints directory
checkpoints_dir = "/content/gpt-neox/checkpoints"

# Read the 'latest' file to get the latest checkpoint name
with open(os.path.join(checkpoints_dir, "latest"), "r") as f:
    latest_checkpoint_name = f.read().strip()

# Construct the full path to the latest checkpoint directory
latest_checkpoint_path = os.path.join(checkpoints_dir, latest_checkpoint_name)
print("Path to the latest checkpoint:", latest_checkpoint_path)
# Out:
# Path to the latest checkpoint: /content/gpt-neox/checkpoints/global_step1000

# %%
# !python ./tools/ckpts/convert_neox_to_hf.py --input_dir {latest_checkpoint_path} --config_file /content/GPT-NeoX-Colab/configs/CC19M.yml --output_dir hf_model/save/location --precision auto --architecture neox
# Out:
# [2024-11-05 20:23:44,083] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Detected 'pipe-parallel-size' of 0, assuming model is saved as Sequential...
# > building GPT2BPETokenizer tokenizer ...
#  > padded vocab (size: 50257) with 47 dummy tokens (new size: 50304)
# Auto-detecting precision to save model into...
# Saving weights in fp16 precision...
# ['sequential.0.word_embeddings.weight', 'sequential.2.input_layernorm.weight', 'sequential.2.input_layernorm.bias', 'sequential.2.attention.query_key_value.weight', 'sequential.2.attention.query_key_value.bias', 'sequential.2.attention.dense.weight', 'sequential.2.attention.dense.bias', 'sequential.2.post_attention_layernorm.weight', 'sequential.2.post_attention_layernorm.bias', 'sequential.2.mlp.linear1.weight', 'sequential.2.mlp.linear1.bias', 'sequential.2.mlp.linear2.weight', 'sequential.2.mlp.linear2.bias', 'sequential.3.input_layernorm.weight', 'sequential.3.input_layernorm.bias', 'sequential.3.attention.query_key_value.weight', 'sequential.3.attention.query_key_value.bias', 'sequential.3.attention.dense.weight', 'sequential.3.attention.dense.bias', 'sequential.3.post_attention_layernorm.weight', 'sequential.3.post_attention_layernorm.bias', 'sequential.3.mlp.linear1.weight', 'sequential.3.mlp.linear1.bias', 'sequential.3.mlp.linear2.weight', 'sequential.3.mlp.linear2.bias', 'sequential.4.input_layernorm.weight', 'sequential.4.input_layernorm.bias', 'sequential.4.attention.query_key_value.weight', 'sequential.4.attention.query_key_value.bias', 'sequential.4.attention.dense.weight', 'sequential.4.attention.dense.bias', 'sequential.4.post_attention_layernorm.weight', 'sequential.4.post_attention_layernorm.bias', 'sequential.4.mlp.linear1.weight', 'sequential.4.mlp.linear1.bias', 'sequential.4.mlp.linear2.weight', 'sequential.4.mlp.linear2.bias', 'sequential.5.input_layernorm.weight', 'sequential.5.input_layernorm.bias', 'sequential.5.attention.query_key_value.weight', 'sequential.5.attention.query_key_value.bias', 'sequential.5.attention.dense.weight', 'sequential.5.attention.dense.bias', 'sequential.5.post_attention_layernorm.weight', 'sequential.5.post_attention_layernorm.bias', 'sequential.5.mlp.linear1.weight', 'sequential.5.mlp.linear1.bias', 'sequential.5.mlp.linear2.weight', 'sequential.5.mlp.linear2.bias', 'sequential.6.input_layernorm.weight', 'sequential.6.input_layernorm.bias', 'sequential.6.attention.query_key_value.weight', 'sequential.6.attention.query_key_value.bias', 'sequential.6.attention.dense.weight', 'sequential.6.attention.dense.bias', 'sequential.6.post_attention_layernorm.weight', 'sequential.6.post_attention_layernorm.bias', 'sequential.6.mlp.linear1.weight', 'sequential.6.mlp.linear1.bias', 'sequential.6.mlp.linear2.weight', 'sequential.6.mlp.linear2.bias', 'sequential.7.input_layernorm.weight', 'sequential.7.input_layernorm.bias', 'sequential.7.attention.query_key_value.weight', 'sequential.7.attention.query_key_value.bias', 'sequential.7.attention.dense.weight', 'sequential.7.attention.dense.bias', 'sequential.7.post_attention_layernorm.weight', 'sequential.7.post_attention_layernorm.bias', 'sequential.7.mlp.linear1.weight', 'sequential.7.mlp.linear1.bias', 'sequential.7.mlp.linear2.weight', 'sequential.7.mlp.linear2.bias', 'sequential.9.norm.weight', 'sequential.9.norm.bias', 'sequential.10.final_linear.weight']
# Detected MLP naming convention: new
# 100% 6/6 [00:00<00:00, 170.07it/s]

# %% [markdown]
# # Code Completion

# %%
from transformers import GPTNeoXForCausalLM
import torch

# Move to model directory
# %cd /content/gpt-neox

# Assuming CharLevelTokenizer is properly imported and instantiated
from megatron.tokenizer.tokenizer import _GPT2BPETokenizer
tokenizer = _GPT2BPETokenizer(vocab_file="data/gpt2-vocab.json", merge_file="data/gpt2-merges.txt")

# Load your model
model_path = "/content/gpt-neox/hf_model/save/location"
model = GPTNeoXForCausalLM.from_pretrained(model_path)

# Define a simple char-level tokenizer if not provided
def token_level_tokenize(text):
    return tokenizer.tokenize(text)

def token_level_detokenize(tokens):
    return tokenizer.detokenize(tokens)

# Set the model to evaluation mode
model.eval()

# Prompt the user for input
input_text = """<s> import sys , os <EOL> import imp <EOL> from optparse import make_option <EOL> from django . conf import settings <EOL> from django . utils . importlib import import_module <EOL> from django . core . management import call_command <EOL> from django . core . management import BaseCommand <EOL> from django . db import connections <EOL> def import_app ( app_label , verbosity ) : <EOL> try : <EOL> app_path = __import__ ( app_label , { } , { } , [ app_label . split ( '<STR_LIT:.>' ) [ - <NUM_LIT:1> ] ] ) . __path__ <EOL>"""

# Tokenize and prepare input
input_ids = torch.tensor([token_level_tokenize(input_text)], dtype=torch.long)
attention_mask = torch.ones_like(input_ids)  # Create an attention mask for non-padded input

# Generate text with specified pad_token_id and attention_mask
with torch.no_grad():
    output = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=200,          # Adjust this for desired output length
        temperature=0.7,        # Controls creativity
        top_k=50,               # Controls diversity
        top_p=0.9,              # Nucleus sampling
        num_return_sequences=1, # Number of sequences to return
        pad_token_id=model.config.eos_token_id,  # Set pad_token_id explicitly
        do_sample=True           # Enable sampling mode to use temperature and top_p
    )

# Decode the generated text
generated_text = token_level_detokenize(output[0].tolist())

# Function to replace special tokens with original representations
def replace_special_tokens(text):
    replacements = {
        "<EOL>": "\n",
        "<s>": "",
        "</s>": "",
        "<STR_LIT>": "STR_LITERAL",  # Example replacement, adjust as necessary
        "<NUM_LIT>": "NUM_LITERAL",   # Example replacement, adjust as necessary
    }

    for token, replacement in replacements.items():
        text = text.replace(token, replacement)

    return text.strip()  # Strip leading/trailing whitespace

# Replace special tokens in the generated text
final_text = replace_special_tokens(generated_text)

# Print the final output
print("Generated text:", final_text)
# Out:
# /content/gpt-neox
# Generated text: import sys, os
#  import imp
#  from optparse import make_option
#  from django. conf import settings
#  from django. utils. importlib import import_module
#  from django. core. management import call_command
#  from django. core. management import BaseCommand
#  from django. db import connections
#  def import_app ( app_label, verbosity ) :
#  try :
#  app_path = __import__ ( app_label, { }, { }, [ app_label. split ( '<STR_LIT:.>' ) [ - <NUM_LIT:1> ] ] ). __path__
#  def __init__ ( self, value, name ) :
#  self. __init__ = self.

# %% [markdown]
# # Benchmark

# %%
# %cd /content/gpt-neox

import torch
from transformers import GPTNeoXForCausalLM

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0)

# Load the model and tokenizer
from megatron.tokenizer.tokenizer import _GPT2BPETokenizer
tokenizer = _GPT2BPETokenizer(vocab_file="data/gpt2-vocab.json", merge_file="data/gpt2-merges.txt")

model_path = "/content/gpt-neox/hf_model/save/location"
model = GPTNeoXForCausalLM.from_pretrained(model_path)

# Define a simple char-level tokenizer if not provided
def token_level_tokenize(text):
    return tokenizer.tokenize(text)

def token_level_detokenize(tokens):
    return tokenizer.detokenize(tokens)

# Read the input file with 5000 code snippets
with open("/content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion/dev.txt", "r", encoding="utf-8") as f:
    documents = f.read().splitlines()

# Initialize predictions.txt as an empty file
with open("prediction.txt", "w", encoding="utf-8") as output_file:
    pass  # Just ensures the file is cleared if it exists

# Open the output file for appending
with open("prediction.txt", "a", encoding="utf-8") as output_file:
    # Process each document one by one
    for document in documents:
        # Skip empty lines
        if not document.strip():
            continue

        # Tokenize the input and ensure it doesn't exceed 200 tokens
        input_ids = token_level_tokenize(document)
        if len(input_ids) > 200:
            input_ids = input_ids[:200]

        # Prepare tensor and attention mask
        input_tensor = torch.tensor([input_ids], dtype=torch.long).to(device)
        attention_mask = torch.ones_like(input_tensor)

        # Set the model to evaluation mode
        model.eval()
        model.to(device)

        # Generate text with specified pad_token_id and attention_mask
        with torch.no_grad():
            output = model.generate(
                input_tensor,
                attention_mask=attention_mask,
                max_length=len(input_ids) + 50,  # max_length slightly greater than input to allow for generation
                temperature=0.7,
                top_k=50,
                top_p=0.9,
                num_return_sequences=1,
                pad_token_id=model.config.eos_token_id,
                do_sample=True
            )

        # Decode and format the generated output
        generated_text = token_level_detokenize(output[0].tolist())

        # Store input text and generated output in the output file
        output_file.write(f"{generated_text}\n")

print("Processing complete. Predictions stored in 'predictions.txt'.")
# Out:
# /content/gpt-neox
# Processing complete. Predictions stored in 'predictions.txt'.

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# %cd /content/CodeXGLUE/Code-Code/CodeCompletion-token
# !ls
# !python evaluator/evaluator.py -a=/content/CodeXGLUE/Code-Code/CodeCompletion-token/dataset/py150/token_completion/dev.txt -p=/content/gpt-neox/prediction.txt
# Out:
# /content/CodeXGLUE/Code-Code/CodeCompletion-token
# code  completion_python_eval.log  dataset  evaluator  README.md
# Traceback (most recent call last):
#   File "/content/CodeXGLUE/Code-Code/CodeCompletion-token/evaluator/evaluator.py", line 36, in <module>
#     main()
#   File "/content/CodeXGLUE/Code-Code/CodeCompletion-token/evaluator/evaluator.py", line 26, in main
#     assert len(pred) == len(gt), f"Sequence length of prediction and answer are not equal, {len(pred)}: {len(gt)}"
# AssertionError: Sequence length of prediction and answer are not equal, 115: 168
